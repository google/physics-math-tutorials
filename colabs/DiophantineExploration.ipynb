# %% [markdown]
# Copyright 2021 Google LLC
#
# Licensed under the Apache License, Version 2.0 (the "License");
# you may not use this file except in compliance with the License.
# You may obtain a copy of the License at
#
#     https://www.apache.org/licenses/LICENSE-2.0
#
# Unless required by applicable law or agreed to in writing, software
# distributed under the License is distributed on an "AS IS" BASIS,
# WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# See the License for the specific language governing permissions and
# limitations under the License.

# %%
#(1/a) + (1/b) + (1/c) = (1/2) 

import itertools
from itertools import permutations

unique__list = []
#temp_list = []
a_list = []
b_list = []
c_list = []

for a in range (1, 100):
  for b in range (1, 100):
      for c in range (1, 100):

        if (1/a) + (1/b) + (1/c) == (1/2): 
          print("a solution to the problem is", a ,  b ,c) 
          a_list.append(a)
          b_list.append(b)
          c_list.append(c)
        

print ("and now for another list")

tester = zip(a_list, b_list, c_list)
tester_list = list(tester)

for index in range(len(tester_list)):
    print (tester_list[index])

dedup_list = []
dedup_list = itertools.combinations(tester_list, 3)

for index in range(len(dedup_list)):
    print (dedup_list[index])


#master_list = []
#for index in range(len(a_list)):
 # master_list.append(a_list[index])

#for index in range(len(a_list)):
  #  print (a_list[index])
  #  print (b_list[index])
  #  print (c_list[index])
# Out:
# a solution to the problem is 3 7 42
# a solution to the problem is 3 8 24
# a solution to the problem is 3 9 18
# a solution to the problem is 3 10 15
# a solution to the problem is 3 15 10
# a solution to the problem is 3 24 8
# a solution to the problem is 4 5 20
# a solution to the problem is 4 8 8
# a solution to the problem is 4 12 6
# a solution to the problem is 4 20 5
# a solution to the problem is 5 4 20
# a solution to the problem is 5 5 10
# a solution to the problem is 5 10 5
# a solution to the problem is 5 20 4
# a solution to the problem is 6 6 6
# a solution to the problem is 6 12 4
# a solution to the problem is 7 3 42
# a solution to the problem is 7 42 3
# a solution to the problem is 8 3 24
# a solution to the problem is 8 4 8
# a solution to the problem is 8 8 4
# a solution to the problem is 8 24 3
# a solution to the problem is 9 3 18
# a solution to the problem is 9 18 3
# a solution to the problem is 10 3 15
# a solution to the problem is 10 5 5
# ...
